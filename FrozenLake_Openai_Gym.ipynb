# %%
import gym

# %%
# make the environment
env = gym.make("FrozenLake-v0")

# %%
# visualize the environment
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
#  #### Markov decision process (MDP) consists of the following:
# - States: A set of states present in the environment.
# - Actions: A set of actions that the agent can perform in each state.
# - Transition probability: The transition probability is denoted by 𝑃(s′|𝑠, a). It implies the probability of moving from a state s to the state 𝑠′  while performing an action a.
# - Reward function: The reward function is denoted by 𝑅(s, a, s′) It implies
# the reward the agent obtains moving from a state s to the state 𝑠′ while  performing an action a.
#
# Let's now understand how to obtain all the above information from the Frozen Lake environment we just created using Gym.

# %% [markdown]
# #### 1.States
# ![image.png](data:image/png;base64,...)

# %%
print(env.observation_space)
# Out:
# Discrete(16)

# %% [markdown]
# #### 2.Actions
# ![image.png](data:image/png;base64,...)

# %%
print(env.action_space)
# Out:
# Discrete(4)

# %% [markdown]
# #### 3.Transition probability and reward function
# Our Frozen Lake environment is a stochastic environment therefore in a stochastic environment we reach the next states with some probability.

# %%
# env.P[state][action].
env.P[0][1]
# the output is in the form of [(transition probability, next state, reward, Is terminal state?)
# Out:
# [(0.3333333333333333, 0, 0.0, False),
#  (0.3333333333333333, 4, 0.0, False),
#  (0.3333333333333333, 1, 0.0, False)]

# %% [markdown]
# ## Generating an episode in the Gym environment

# %%
# initialize the state by resetting our environment
state = env.reset()

# %% [markdown]
# #### 1.Action selection

# %%
env.render()

print(env.step(2))  # take an action to go right 
# the output is in the form of (next_state, reward, done, info)

env.render()
# Out:
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# (1, 0.0, False, {'prob': 0.3333333333333333})
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# take a random action
random_action = env.action_space.sample()
env.step(random_action)
env.render()
# Out:
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# ### Generating an episode

# %%
import gym

env = gym.make("FrozenLake-v0")

env.reset()

print('Time Step 0 :')
env.render()

# number of time steps
num_timesteps = 20

for t in range(num_timesteps):
  random_action = env.action_space.sample()
  (next_state, reward, done, info) = env.step(random_action)
  print ('Time Step {} :'.format(t+1))
  env.render()
  if done==True:
        break
# Out:
# Time Step 0 :
#
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 1 :
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 2 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# Instead of generating one episode, we can also generate a series of episodes by taking some random action in each state:

# %%
import gym
env = gym.make("FrozenLake-v0")

num_episodes = 5
num_timesteps = 20 
for i in range(num_episodes):
    
    state = env.reset()
    print('Episode number {} :'.format(i+1))
    env.render()
    for t in range(num_timesteps):
        random_action = env.action_space.sample()
        
        new_state, reward, done, info = env.step(random_action)
        print ('Time Step {} :'.format(t+1))

        env.render()
        if done:
            break
# Out:
# Episode number 1 :
#
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 1 :
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 2 :
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 3 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 4 :
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 5 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 6 :
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 7 :
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 8 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Episode number 2 :
#
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 1 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 2 :
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Episode number 3 :
#
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 1 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 2 :
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 3 :
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 4 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 5 :
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Time Step 6 :
#   (Left)
# ...
